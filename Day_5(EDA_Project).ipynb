# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ***EDA***

# %%
data = pd.read_csv("/content/train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data['Age'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
data['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
data[data['Age']>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
data['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
data['Fare'].head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# ### **All Operations-->**
# head()
# tail()
# sample()
# shape
# size
# columns
# index
# dtypes
# info()
# describe()
# isnull()
# notnull()
# sum()
# dropna()
# fillna()
# duplicated()
# drop_duplicates()
# nunique()
# unique()
# value_counts()
# sort_values()
# min()
# max()
# mean()
# median()
# mode()
# std()
# var()
# corr()
# cov()
# groupby()
# count()
# loc[]
# iloc[]
# query()
# rename()
# drop()
# hist()
# boxplot()
# histplot()
# scatterplot()
# countplot()
# pairplot()
# heatmap()
# show()

# %%
data = pd.read_csv("/content/archive (8).zip")
data.head()
# Out:
#    Year  Facility_ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 2  2021  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 3  2022  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 4  2023  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
# 2   Spain  Enterprise/Standard                   6.47  1.928
# 3   Spain  Enterprise/Standard                   6.59  1.897
# 4   Spain  Enterprise/Standard                   6.70  1.869
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# ...

# %%
data.tail()
# Out:
#         Year  Facility_ID       Facility_Name  \
# 126765  2021  DC-31D8B15E  ICS_DataCenter_216
# 126766  2022  DC-31D8B15E  ICS_DataCenter_216
# 126767  2023  DC-31D8B15E  ICS_DataCenter_216
# 126768  2024  DC-31D8B15E  ICS_DataCenter_216
# 126769  2025  DC-31D8B15E  ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 126765  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126766  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126767  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126768  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
# 126769  ICS BİLİŞİM TEKNOLOJİLERİ DANIŞMANLIK HİZMETLE...  Unknown  Türkiye
#
#               Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 126765  Enterprise/Standard                  14.51  1.495         Evaporative
# ...

# %%
data.sample()
# Out:
#         Year  Facility_ID              Facility_Name Owner_Company     City  \
# 124451  2024  DC-79E289AF  FIN01 Finland Data Center       atNorth  Unknown
#
#         Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 124451  Finland  Enterprise/Standard                  14.99  1.488
#
#        Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 124451         Evaporative           2.39                       465.93
#
#         Daily_Water_Usage_Gallons Surrounding_Water_Stress_Tier
# 124451                  197634.01                        Medium

# %%
data.shape
# Out:
# (126770, 14)

# %%
data.size
# Out:
# 1774780

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126770 entries, 0 to 126769
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Year                           126770 non-null  int64
#  1   Facility_ID                    126770 non-null  object
#  2   Facility_Name                  126770 non-null  object
#  3   Owner_Company                  126770 non-null  object
#  4   City                           126770 non-null  object
#  5   Country                        126770 non-null  object
#  6   Facility_Type                  126770 non-null  object
#  7   Estimated_Capacity_MW          126770 non-null  float64
#  8   PUE                            126770 non-null  float64
#  9   Cooling_System_Type            126770 non-null  object
#  10  WUE_L_per_kWh                  126770 non-null  float64
#  11  Daily_Electricity_Usage_MWh    126770 non-null  float64
# ...

# %%
data.dtypes
# Out:
# Year                               int64
# Facility_ID                       object
# Facility_Name                     object
# Owner_Company                     object
# City                              object
# Country                           object
# Facility_Type                     object
# Estimated_Capacity_MW            float64
# PUE                              float64
# Cooling_System_Type               object
# WUE_L_per_kWh                    float64
# Daily_Electricity_Usage_MWh      float64
# Daily_Water_Usage_Gallons        float64
# Surrounding_Water_Stress_Tier     object
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=126770, step=1)

# %%
data.columns
# Out:
# Index(['Year', 'Facility_ID', 'Facility_Name', 'Owner_Company', 'City',
#        'Country', 'Facility_Type', 'Estimated_Capacity_MW', 'PUE',
#        'Cooling_System_Type', 'WUE_L_per_kWh', 'Daily_Electricity_Usage_MWh',
#        'Daily_Water_Usage_Gallons', 'Surrounding_Water_Stress_Tier'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Year  Estimated_Capacity_MW            PUE  WUE_L_per_kWh  \
# count  126770.000000          126770.000000  126770.000000  126770.000000
# mean     2022.000000              23.075117       1.637746       0.820596
# std         2.000008              45.847195       0.190833       0.925481
# min      2019.000000               1.000000       1.057000       0.001000
# 25%      2020.000000               5.450000       1.518000       0.139000
# 50%      2022.000000               9.870000       1.643000       0.232000
# 75%      2024.000000              14.180000       1.787000       1.654000
# max      2025.000000             562.890000       2.000000       3.000000
#
#        Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons
# count                126770.000000               1.267700e+05
# mean                    605.222368               1.312182e+05
# std                    1040.061940               3.979629e+05
# ...

# %%
data.isnull()
# Out:
#          Year  Facility_ID  Facility_Name  Owner_Company   City  Country  \
# 0       False        False          False          False  False    False
# 1       False        False          False          False  False    False
# 2       False        False          False          False  False    False
# 3       False        False          False          False  False    False
# 4       False        False          False          False  False    False
# ...       ...          ...            ...            ...    ...      ...
# 126765  False        False          False          False  False    False
# 126766  False        False          False          False  False    False
# 126767  False        False          False          False  False    False
# 126768  False        False          False          False  False    False
# 126769  False        False          False          False  False    False
#
#         Facility_Type  Estimated_Capacity_MW    PUE  Cooling_System_Type  \
# ...

# %%
data.notnull()
# Out:
#         Year  Facility_ID  Facility_Name  Owner_Company  City  Country  \
# 0       True         True           True           True  True     True
# 1       True         True           True           True  True     True
# 2       True         True           True           True  True     True
# 3       True         True           True           True  True     True
# 4       True         True           True           True  True     True
# ...      ...          ...            ...            ...   ...      ...
# 126765  True         True           True           True  True     True
# 126766  True         True           True           True  True     True
# 126767  True         True           True           True  True     True
# 126768  True         True           True           True  True     True
# 126769  True         True           True           True  True     True
#
#         Facility_Type  Estimated_Capacity_MW   PUE  Cooling_System_Type  \
# ...

# %%
data.fillna(10)
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 2                                               Terremark   Madrid    Spain
# ...

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 126765    False
# 126766    False
# 126767    False
# 126768    False
# 126769    False
# Length: 126770, dtype: bool

# %%
data.drop_duplicates()
# Out:
#         Year  Facility_ID               Facility_Name  \
# 0       2019  DC-D2763E00  NAP de las Americas Madrid
# 1       2020  DC-D2763E00  NAP de las Americas Madrid
# 2       2021  DC-D2763E00  NAP de las Americas Madrid
# 3       2022  DC-D2763E00  NAP de las Americas Madrid
# 4       2023  DC-D2763E00  NAP de las Americas Madrid
# ...      ...          ...                         ...
# 126765  2021  DC-31D8B15E          ICS_DataCenter_216
# 126766  2022  DC-31D8B15E          ICS_DataCenter_216
# 126767  2023  DC-31D8B15E          ICS_DataCenter_216
# 126768  2024  DC-31D8B15E          ICS_DataCenter_216
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company     City  Country  \
# 0                                               Terremark   Madrid    Spain
# 1                                               Terremark   Madrid    Spain
# 2                                               Terremark   Madrid    Spain
# ...

# %%
data.nunique()
# Out:
# Year                                  7
# Facility_ID                       18110
# Facility_Name                     16286
# Owner_Company                      4180
# City                               2513
# Country                             344
# Facility_Type                         3
# Estimated_Capacity_MW             13888
# PUE                                 941
# Cooling_System_Type                   3
# WUE_L_per_kWh                      2233
# Daily_Electricity_Usage_MWh       65027
# Daily_Water_Usage_Gallons        124815
# Surrounding_Water_Stress_Tier         3
# dtype: int64

# %%
data['Year'].unique()
# Out:
# array([2019, 2020, 2021, 2022, 2023, 2024, 2025])

# %%
data.value_counts()
# Out:
# Year  Facility_ID  Facility_Name                           Owner_Company                  City        Country        Facility_Type        Estimated_Capacity_MW  PUE    Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons  Surrounding_Water_Stress_Tier
# 2025  DC-FFED2F44  Kolding                                 house4IT Hosting               Kolding     Denmark        Enterprise/Standard  11.47                  1.788  Air Cooled           0.266          303.88                       11950.40                   Low                              1
# 2019  DC-0006E5D5  Giza                                    ECC Solutions                  Giza        Egypt          Enterprise/Standard  5.06                   1.555  Evaporative          1.644          147.79                       41287.35                   Low                              1
# ...

# %%
data.sort_values(by='Year')
# Out:
#         Year  Facility_ID               Facility_Name  \
# 63      2019  DC-4E79E5A8                1 Brick Lane
# 35      2019  DC-F3250F8F     National Bank of Kuwait
# 78456   2019  DC-E96273B0  The Dalles, OR Data Center
# 78449   2019  DC-A4652F9B   San Antonio (SN7) - Texas
# 18151   2019  DC-42982623                       Hanoi
# ...      ...          ...                         ...
# 27      2025  DC-40C11C98               Etix Accra #1
# 126755  2025  DC-6ED48AF1      Gayrettepe Data Center
# 20      2025  DC-F1A55D5B                 Cluj-Napoca
# 126762  2025  DC-69F89A63   Teknet Datacenter Antalya
# 126769  2025  DC-31D8B15E          ICS_DataCenter_216
#
#                                             Owner_Company         City  \
# 63                                              Interoute       London
# 35                          National Bank of Kuwait (NBK)    Farwaniya
# 78456                                              Google      Unknown
# ...

# %%
data.max()
# Out:
# Year                                                                 2025
# Facility_ID                                                   DC-FFED2F44
# Facility_Name                    仙台中央テータセンター (Sendai Central Data Center)
# Owner_Company                                              Петя Симеонова
# City                                                                   香港
# Country                                                        １３ 県道147号線
# Facility_Type                                               Hyperscale/AI
# Estimated_Capacity_MW                                              562.89
# PUE                                                                   2.0
# Cooling_System_Type                                         Liquid Cooled
# WUE_L_per_kWh                                                         3.0
# Daily_Electricity_Usage_MWh                                      14812.66
# Daily_Water_Usage_Gallons                                      7585092.35
# ...

# %%
data.min()
# Out:
# Year                                           2019
# Facility_ID                             DC-0006E5D5
# Facility_Name                         0 Rocky Creek
# Owner_Company                    1&1 Internet, Inc.
# City                                           #100
# Country                                      030400
# Facility_Type                            Colocation
# Estimated_Capacity_MW                           1.0
# PUE                                           1.057
# Cooling_System_Type                      Air Cooled
# WUE_L_per_kWh                                 0.001
# Daily_Electricity_Usage_MWh                   22.19
# Daily_Water_Usage_Gallons                    224.01
# Surrounding_Water_Stress_Tier                  High
# dtype: object

# %%
data.mean(numeric_only=True)
# Out:
# Year                             2022.000000
# Estimated_Capacity_MW              23.075117
# PUE                                 1.637746
# WUE_L_per_kWh                       0.820596
# Daily_Electricity_Usage_MWh       605.222368
# Daily_Water_Usage_Gallons      131218.164755
# dtype: float64

# %%
data.median(numeric_only=True)
# Out:
# Year                            2022.000
# Estimated_Capacity_MW              9.870
# PUE                                1.643
# WUE_L_per_kWh                      0.232
# Daily_Electricity_Usage_MWh      302.750
# Daily_Water_Usage_Gallons      12181.295
# dtype: float64

# %%
data.mode(numeric_only=True)
# Out:
#       Year  Estimated_Capacity_MW    PUE  WUE_L_per_kWh  \
# 0   2019.0                  11.63  1.508          0.147
# 1   2020.0                    NaN  1.541            NaN
# 2   2021.0                    NaN    NaN            NaN
# 3   2022.0                    NaN    NaN            NaN
# 4   2023.0                    NaN    NaN            NaN
# 5   2024.0                    NaN    NaN            NaN
# 6   2025.0                    NaN    NaN            NaN
# 7      NaN                    NaN    NaN            NaN
# 8      NaN                    NaN    NaN            NaN
# 9      NaN                    NaN    NaN            NaN
# 10     NaN                    NaN    NaN            NaN
# 11     NaN                    NaN    NaN            NaN
# 12     NaN                    NaN    NaN            NaN
# 13     NaN                    NaN    NaN            NaN
# 14     NaN                    NaN    NaN            NaN
# 15     NaN                    NaN    NaN            NaN
# ...

# %%
data.std(numeric_only=True)
# Out:
# Year                                2.000008
# Estimated_Capacity_MW              45.847195
# PUE                                 0.190833
# WUE_L_per_kWh                       0.925481
# Daily_Electricity_Usage_MWh      1040.061940
# Daily_Water_Usage_Gallons      397962.899982
# dtype: float64

# %%
data.corr(numeric_only=True)
# Out:
#                                  Year  Estimated_Capacity_MW       PUE  \
# Year                         1.000000               0.093442 -0.190219
# Estimated_Capacity_MW        0.093442               1.000000 -0.601272
# PUE                         -0.190219              -0.601272  1.000000
# WUE_L_per_kWh               -0.031329               0.182441 -0.160029
# Daily_Electricity_Usage_MWh  0.083897               0.983549 -0.576587
# Daily_Water_Usage_Gallons    0.060377               0.791200 -0.484959
#
#                              WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# Year                             -0.031329                     0.083897
# Estimated_Capacity_MW             0.182441                     0.983549
# PUE                              -0.160029                    -0.576587
# WUE_L_per_kWh                     1.000000                     0.184339
# Daily_Electricity_Usage_MWh       0.184339                     1.000000
# ...

# %%
data.var(numeric_only=True)
# Out:
# Year                           4.000032e+00
# Estimated_Capacity_MW          2.101965e+03
# PUE                            3.641713e-02
# WUE_L_per_kWh                  8.565159e-01
# Daily_Electricity_Usage_MWh    1.081729e+06
# Daily_Water_Usage_Gallons      1.583745e+11
# dtype: float64

# %%
data.cov(numeric_only=True)
# Out:
#                                      Year  Estimated_Capacity_MW  \
# Year                             4.000032           8.568166e+00
# Estimated_Capacity_MW            8.568166           2.101965e+03
# PUE                             -0.072600          -5.260616e+00
# WUE_L_per_kWh                   -0.057989           7.741100e+00
# Daily_Electricity_Usage_MWh    174.516020           4.689949e+04
# Daily_Water_Usage_Gallons    48056.140635           1.443582e+07
#
#                                       PUE  WUE_L_per_kWh  \
# Year                            -0.072600      -0.057989
# Estimated_Capacity_MW           -5.260616       7.741100
# PUE                              0.036417      -0.028263
# WUE_L_per_kWh                   -0.028263       0.856516
# Daily_Electricity_Usage_MWh   -114.439660     177.437094
# Daily_Water_Usage_Gallons   -36829.929163  152348.324000
#
#                              Daily_Electricity_Usage_MWh  \
# ...

# %%
data.groupby('Facility_Type')['Daily_Water_Usage_Gallons'].mean(numeric_only=True)
# Out:
# Facility_Type
# Colocation             2.983745e+05
# Enterprise/Standard    3.003673e+04
# Hyperscale/AI          1.074522e+06
# Name: Daily_Water_Usage_Gallons, dtype: float64

# %%
data.count()
# Out:
# Year                             126770
# Facility_ID                      126770
# Facility_Name                    126770
# Owner_Company                    126770
# City                             126770
# Country                          126770
# Facility_Type                    126770
# Estimated_Capacity_MW            126770
# PUE                              126770
# Cooling_System_Type              126770
# WUE_L_per_kWh                    126770
# Daily_Electricity_Usage_MWh      126770
# Daily_Water_Usage_Gallons        126770
# Surrounding_Water_Stress_Tier    126770
# dtype: int64

# %%
data.loc[0]
# Out:
# Year                                                   2019
# Facility_ID                                     DC-D2763E00
# Facility_Name                    NAP de las Americas Madrid
# Owner_Company                                     Terremark
# City                                                 Madrid
# Country                                               Spain
# Facility_Type                           Enterprise/Standard
# Estimated_Capacity_MW                                  6.24
# PUE                                                   1.975
# Cooling_System_Type                             Evaporative
# WUE_L_per_kWh                                         1.481
# Daily_Electricity_Usage_MWh                          183.62
# Daily_Water_Usage_Gallons                          36362.94
# Surrounding_Water_Stress_Tier                           Low
# Name: 0, dtype: object

# %%
data.iloc[1]
# Out:
# Year                                                   2020
# Facility_ID                                     DC-D2763E00
# Facility_Name                    NAP de las Americas Madrid
# Owner_Company                                     Terremark
# City                                                 Madrid
# Country                                               Spain
# Facility_Type                           Enterprise/Standard
# Estimated_Capacity_MW                                  6.36
# PUE                                                   1.967
# Cooling_System_Type                             Evaporative
# WUE_L_per_kWh                                         1.459
# Daily_Electricity_Usage_MWh                          254.34
# Daily_Water_Usage_Gallons                           49833.6
# Surrounding_Water_Stress_Tier                           Low
# Name: 1, dtype: object

# %%
data.rename(columns={'Facility_ID': 'ID'}).head(2)
# Out:
#    Year           ID               Facility_Name Owner_Company    City  \
# 0  2019  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
# 1  2020  DC-D2763E00  NAP de las Americas Madrid     Terremark  Madrid
#
#   Country        Facility_Type  Estimated_Capacity_MW    PUE  \
# 0   Spain  Enterprise/Standard                   6.24  1.975
# 1   Spain  Enterprise/Standard                   6.36  1.967
#
#   Cooling_System_Type  WUE_L_per_kWh  Daily_Electricity_Usage_MWh  \
# 0         Evaporative          1.481                       183.62
# 1         Evaporative          1.459                       254.34
#
#    Daily_Water_Usage_Gallons Surrounding_Water_Stress_Tier
# 0                   36362.94                           Low
# 1                   49833.60                           Low

# %%
data.drop(columns=['Facility_ID']).head(2)
# Out:
#    Year               Facility_Name Owner_Company    City Country  \
# 0  2019  NAP de las Americas Madrid     Terremark  Madrid   Spain
# 1  2020  NAP de las Americas Madrid     Terremark  Madrid   Spain
#
#          Facility_Type  Estimated_Capacity_MW    PUE Cooling_System_Type  \
# 0  Enterprise/Standard                   6.24  1.975         Evaporative
# 1  Enterprise/Standard                   6.36  1.967         Evaporative
#
#    WUE_L_per_kWh  Daily_Electricity_Usage_MWh  Daily_Water_Usage_Gallons  \
# 0          1.481                       183.62                   36362.94
# 1          1.459                       254.34                   49833.60
#
#   Surrounding_Water_Stress_Tier
# 0                           Low
# 1                           Low

# %%
data['Daily_Water_Usage_Gallons'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data['Daily_Water_Usage_Gallons'])
# Out:
# <Axes: xlabel='Daily_Water_Usage_Gallons', ylabel='Count'>

# %%
data["Daily_Water_Usage_Gallons"].plot(kind="box")
# Out:
# <Axes: >

# %%
sns.boxplot(data["Daily_Water_Usage_Gallons"])
# Out:
# <Axes: ylabel='Daily_Water_Usage_Gallons'>

# %%
sns.scatterplot(data, x="Daily_Water_Usage_Gallons", y="Year")
# Out:
# <Axes: xlabel='Daily_Water_Usage_Gallons', ylabel='Year'>

# %%
sns.pairplot(data, vars=["Daily_Water_Usage_Gallons"], hue="Year")

# %%
sns.heatmap(data.corr(numeric_only=True)[["Daily_Water_Usage_Gallons"]],annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### ***Loan Approval Analysis-->***

# %%
data = pd.read_csv("/content/loan_sanction_train.csv")
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.countplot(data, x='Loan_Status')
plt.title('Distribution of Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Count')
plt.show()

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)

data['Married'].fillna(data['Married'].mode()[0], inplace=True)

data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)

data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)

data['LoanAmount'].fillna(data['LoanAmount'].median(), inplace=True)

data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)

data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)

data.isnull().sum()
# Out:
# /tmp/ipykernel_5009/1319267764.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)
# /tmp/ipykernel_5009/1319267764.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
sns.countplot(data, x='Credit_History', hue='Loan_Status')
plt.title('Loan Status by Credit History')
plt.xlabel('Credit History ')
plt.ylabel('Count')
plt.show()

# %%
a = pd.crosstab(data['Credit_History'], data['Loan_Status'], normalize='index') * 100
a
a.plot(kind='bar', stacked=True)
plt.title('Percentage of Loan Status by Credit History')
plt.xlabel('Credit History')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()

# %%
sns.histplot(data['LoanAmount'], kde=True, bins=30)
plt.title('Distribution of Loan Amount')
plt.xlabel('Loan Amount (in thousands)')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x=data['LoanAmount'])
plt.title('Box Plot of Loan Amount')
plt.xlabel('Loan Amount (in thousands)')
plt.show()

# %%
sns.countplot(data, x='Gender', hue='Loan_Status')
plt.title('Loan Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
gender_loan_status = pd.crosstab(data['Gender'], data['Loan_Status'], normalize='index') * 100
display(gender_loan_status)
gender_loan_status.plot(kind='bar', stacked=True)
plt.title('Percentage of Loan Status by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()
# Out:
# Loan_Status          N          Y
# Gender
# Female       33.035714  66.964286
# Male         30.876494  69.123506

# %%
sns.countplot(data, x='Married', hue='Loan_Status')
plt.title('Loan Status by Married Status')
plt.xlabel('Married')
plt.ylabel('Count')
plt.show()

# %%
married_loan_status = pd.crosstab(data['Married'], data['Loan_Status'], normalize='index') * 100
display(married_loan_status)
married_loan_status.plot(kind='bar', stacked=True,)
plt.title('Percentage of Loan Status by Married Status')
plt.xlabel('Married')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend()
plt.show()
# Out:
# Loan_Status          N          Y
# Married
# No           37.089202  62.910798
# Yes          28.179551  71.820449
